# %% [markdown]
# # LangGraph End-to-End SAP Drafting
# This streamlined notebook imports the pre-built graph directly from `workflow.py` and executes it, just like `main_langgraph.py` does.

# %%
import os
import json
from pathlib import Path
from dotenv import load_dotenv

# --- SET PROJECT CONFIG HERE ---
os.environ["VERTEXAI_PROJECT"] = ""
os.environ["VERTEXAI_LOCATION"] = "us-central1"
os.environ["LLM_BACKEND"] = "vertex_ai"
os.environ["MODEL_NAME"] = "gemini-2.5-flash"
os.environ["LANGCHAIN_TRACING_V2"] = "false"

# Load fallback .env
base_dir = Path.cwd()
load_dotenv(base_dir / ".env")

print(f"--- Starting LangGraph Demo 4 ---")
print(f"Using Model: {os.getenv('MODEL_NAME')}")
# Out:
# --- Starting LangGraph Demo 4 ---
# Using Model: gemini-2.5-flash

# %%
# --- Import the Pre-Built Graph from workflow.py ---
from workflow import build_graph

data_dir = base_dir / "data"
output_dir = base_dir / "outputs"
output_dir.mkdir(parents=True, exist_ok=True)

# Define the starting memory payload
initial_state = {
    "protocol_path": str(data_dir / "protocol.docx"),
    "template_path": str(data_dir / "sap_template.docx"),
    "protocol_json_path": str(output_dir / "protocol_parsed.json"),
    "template_json_path": str(output_dir / "sap_template_parsed.json"),
    "protocol_tables_json_path": str(output_dir / "protocol_tables.json"),
    "update_units_json_path": str(output_dir / "update_units.json"),
    "drafted_sap_json_path": str(output_dir / "drafted_sap_updates.json"), 
    "summary_txt_path": str(output_dir / "summary.txt"),
}
# Out:
# /home/jupyter/phds/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.cloud.aiplatform_v1beta1 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.aiplatform_v1beta1 past that date.
#   warnings.warn(message, FutureWarning)
# /home/jupyter/phds/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.cloud.aiplatform_v1 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.aiplatform_v1 past that date.
#   warnings.warn(message, FutureWarning)
# /home/jupyter/phds/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.cloud.resourcemanager_v3 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.resourcemanager_v3 past that date.
#   warnings.warn(message, FutureWarning)
# /home/jupyter/phds/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.cloud.aiplatform.v1.schema.predict.instance_v1 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.aiplatform.v1.schema.predict.instance_v1 past that date.
#   warnings.warn(message, FutureWarning)
# /home/jupyter/phds/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.cloud.aiplatform.v1.schema.predict.params_v1 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.aiplatform.v1.schema.predict.params_v1 past that date.
#   warnings.warn(message, FutureWarning)
# /home/jupyter/phds/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.cloud.aiplatform.v1.schema.predict.prediction_v1 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.aiplatform.v1.schema.predict.prediction_v1 past that date.
#   warnings.warn(message, FutureWarning)
# /home/jupyter/phds/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.cloud.aiplatform.v1.schema.trainingjob.definition_v1 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.aiplatform.v1.schema.trainingjob.definition_v1 past that date.
#   warnings.warn(message, FutureWarning)
# /home/jupyter/phds/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.cloud.aiplatform.v1beta1.schema.predict.instance_v1beta1 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.aiplatform.v1beta1.schema.predict.instance_v1beta1 past that date.
#   warnings.warn(message, FutureWarning)
# /home/jupyter/phds/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.cloud.aiplatform.v1beta1.schema.predict.params_v1beta1 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.aiplatform.v1beta1.schema.predict.params_v1beta1 past that date.
#   warnings.warn(message, FutureWarning)
# /home/jupyter/phds/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.cloud.aiplatform.v1beta1.schema.predict.prediction_v1beta1 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.aiplatform.v1beta1.schema.predict.prediction_v1beta1 past that date.
#   warnings.warn(message, FutureWarning)
# /home/jupyter/phds/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.cloud.aiplatform.v1beta1.schema.trainingjob.definition_v1beta1 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.aiplatform.v1beta1.schema.trainingjob.definition_v1beta1 past that date.
#   warnings.warn(message, FutureWarning)
# /home/jupyter/phds/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.cloud.vectorsearch_v1beta once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.vectorsearch_v1beta past that date.
#   warnings.warn(message, FutureWarning)

# %%
# --- Execute the Graph ---
app = build_graph()

# Concurrency limit of 1 ensures pure sequential execution
final_state = app.invoke(initial_state, config={"recursion_limit": 50, "max_concurrency": 1})

summary = {
    "protocol_paragraphs": final_state.get("parsed_protocol", {}).get("paragraph_count", 0),
    "protocol_tables": len(final_state.get("protocol_tables", [])),
    "detected_update_units": len(final_state.get("update_units", [])),
    "drafted_sap_updates": len(final_state.get("drafted_sap_updates", [])),
    "drafted_file_saved_at": final_state.get("drafted_sap_json_path", "")
}

summary_path = output_dir / "demo4_summary.json"
summary_path.write_text(json.dumps(summary, indent=2, ensure_ascii=False), encoding="utf-8")

print("\n✅ LangGraph Pipeline Completed Successfully!")
print(json.dumps(summary, indent=2, ensure_ascii=False))
# Out:
# --- NODE: Parsing Documents ---
# --- NODE: Extracting Tables ---
# --- NODE: Detecting Template Signals ---
# --- NODE: Drafting SAP Updates (One-by-One) ---
#    -> Processing unit 1/19 (ID: U0001)...
# /home/jupyter/phdemo/demo4/config/llm_config_langchain.py:40: LangChainDeprecationWarning: The class `ChatVertexAI` was deprecated in LangChain 3.2.0 and will be removed in 4.0.0. An updated version of the class exists in the `langchain-google-genai package and should be used instead. To use it run `pip install -U `langchain-google-genai` and import as `from `langchain_google_genai import ChatGoogleGenerativeAI``.
#   base_llm = ChatVertexAI(
#       [Success] Drafted: Zinc sulfate (or other zinc salt) accept...
#    -> Processing unit 2/19 (ID: U0002)...
#       [Success] Drafted: ABC-1234...
#    -> Processing unit 3/19 (ID: U0003)...
#       [Success] Drafted: Zinc sulfate (or other zinc salt)...
#    -> Processing unit 4/19 (ID: U0004)...
#       [Success] Drafted: Zinc acceptability study in children wit...
#    -> Processing unit 5/19 (ID: U0005)...
#       [Success] Drafted: ABC Pharmaceuticals...
#    -> Processing unit 6/19 (ID: U0006)...
#       [Success] Drafted: Not specified in protocol...
#    -> Processing unit 7/19 (ID: U0007)...
#       [Success] Drafted: Not specified in protocol...
#    -> Processing unit 8/19 (ID: U0008)...
#       [Success] Drafted: To evaluate acceptability of the zinc pr...
#    -> Processing unit 9/19 (ID: U0009)...
#       [Success] Drafted: The secondary objective is to assess pal...
#    -> Processing unit 10/19 (ID: U0010)...
#       [Success] Drafted: Not specified in protocol...
#    -> Processing unit 11/19 (ID: U0011)...
#       [Success] Drafted: The primary endpoint is the acceptabilit...
#    -> Processing unit 12/19 (ID: U0012)...
# Retrying langchain_google_vertexai.chat_models._completion_with_retry.<locals>._completion_with_retry_inner in 4 seconds as it raised ResourceExhausted: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details..
#       [Success] Drafted: The secondary objective is to assess pal...
#    -> Processing unit 13/19 (ID: U0013)...
#       [Success] Drafted: Not specified in protocol...
#    -> Processing unit 14/19 (ID: U0014)...
#       [Success] Drafted: ...
#    -> Processing unit 15/19 (ID: U0015)...
# Retrying langchain_google_vertexai.chat_models._completion_with_retry.<locals>._completion_with_retry_inner in 4 seconds as it raised ResourceExhausted: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details..
#       [Success] Drafted: ...
#    -> Processing unit 16/19 (ID: U0016)...
#       [Success] Drafted: The primary statistical hypothesis is to...
#    -> Processing unit 17/19 (ID: U0017)...
#       [Success] Drafted: Not specified in protocol...
#    -> Processing unit 18/19 (ID: U0018)...
#       [Success] Drafted: Not specified in protocol...
#    -> Processing unit 19/19 (ID: U0019)...
#       [Success] Drafted: Missing data may occur due to incomplete...
#
# ✅ LangGraph Pipeline Completed Successfully!
# {
#   "protocol_paragraphs": 218,
#   "protocol_tables": 1,
#   "detected_update_units": 19,
#   "drafted_sap_updates": 19,
#   "drafted_file_saved_at": "/home/jupyter/phdemo/demo4/outputs/drafted_sap_updates.json"
# }

# %%
# --- Generate Final Word Document ---
print("\n--- Generating Final Word Document ---")
from sap_document_builder import build_final_sap_docx

final_docx_path = str(output_dir / "Draft_SAP_v1.docx")

build_final_sap_docx(
    template_docx_path=initial_state["template_path"],
    update_units_path=initial_state["update_units_json_path"],
    draft_json_path=initial_state["drafted_sap_json_path"],
    output_docx_path=final_docx_path
)
# Out:
# --- Generating Final Word Document ---
# Loading template from: /home/jupyter/phdemo/demo4/data/sap_template.docx
# Success! Replaced 19 placeholders.
# Final SAP draft saved to: /home/jupyter/phdemo/demo4/outputs/Draft_SAP_v1.docx
